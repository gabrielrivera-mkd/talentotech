# %%
animales_lista = ["delfín", "pulpo", "tiburón", "ballena", "estrella de mar"]
print("Lista:", animales_lista)


animales_tupla = ("delfín", "pulpo", "tiburón", "ballena", "estrella de mar")
print("Tupla:", animales_tupla)

animales_conjunto = {"delfín", "pulpo", "tiburón", "ballena", "estrella de mar"}
print("Conjunto:", animales_conjunto)


animales_diccionario = {
    "delfín": "mamífero marino muy inteligente",
    "pulpo": "molusco con 8 brazos",
    "tiburón": "pez depredador",
    "ballena": "mamífero marino gigante",
    "estrella de mar": "invertebrado con forma de estrella"
}
print("Diccionario:", animales_diccionario)


animales_lista = ["delfín", "pulpo", "tiburón", "ballena", "estrella de mar"]

print("Recorriendo la lista:")
for animal in animales_lista:
    print(animal)

    animales_tupla = ("delfín", "pulpo", "tiburón", "ballena", "estrella de mar")

print("Recorriendo la tupla:")
for animal in animales_tupla:
    print(animal)

    animales_conjunto = {"delfín", "pulpo", "tiburón", "ballena", "estrella de mar"}

print("Recorriendo el conjunto:")
for animal in animales_conjunto:
    print(animal)

    animales_diccionario = {
    "delfín": "mamífero marino muy inteligente",
    "pulpo": "molusco con 8 brazos",
    "tiburón": "pez depredador",
    "ballena": "mamífero marino gigante",
    "estrella de mar": "invertebrado con forma de estrella"
}

print("Recorriendo el diccionario:")
for clave, valor in animales_diccionario.items():
    print(f"{clave}: {valor}")
# Out:
# Lista: ['delfín', 'pulpo', 'tiburón', 'ballena', 'estrella de mar']
# Tupla: ('delfín', 'pulpo', 'tiburón', 'ballena', 'estrella de mar')
# Conjunto: {'ballena', 'estrella de mar', 'tiburón', 'pulpo', 'delfín'}
# Diccionario: {'delfín': 'mamífero marino muy inteligente', 'pulpo': 'molusco con 8 brazos', 'tiburón': 'pez depredador', 'ballena': 'mamífero marino gigante', 'estrella de mar': 'invertebrado con forma de estrella'}
# Recorriendo la lista:
# delfín
# pulpo
# tiburón
# ballena
# estrella de mar
# Recorriendo la tupla:
# delfín
# pulpo
# tiburón
# ballena
# estrella de mar
# Recorriendo el conjunto:
# ballena
# estrella de mar
# tiburón
# pulpo
# delfín
# Recorriendo el diccionario:
# delfín: mamífero marino muy inteligente
# pulpo: molusco con 8 brazos
# tiburón: pez depredador
# ballena: mamífero marino gigante
# estrella de mar: invertebrado con forma de estrella
