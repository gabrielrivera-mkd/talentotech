# %%
# Datos
animales_lista = ["delfín", "pulpo", "tiburón", "ballena", "estrella de mar"]
animales_tupla = ("medusa", "caballito de mar", "manta raya")  # Animales nuevos no modificables
animales_conjunto = {"pez payaso", "orca", "cangrejo", "anguila", "calamar"}  # Sin repeticiones

# Diccionario con descripción y precio
catalogo = {
    "DELFIN"          : {"desc": "Mamífero marino inteligente", "precio":                                                                     3000},
    "pulpo"           : {"desc": "Molusco con ocho brazos", "precio":                                                                          550},
    "tiburón"         : {"desc": "Pez depredador", "precio":                                                                                  5000},
    "ballena"         : {"desc": "Gigante del océano", "precio":                                                                             10000},
    "estrella de mar" : {"desc": "Invertebrado con forma de estrella", "precio":                                                               450},
    "calamar"         : {"desc": "Molusco de cuerpo blando que vive en agua salada.", "precio":                                                350},
    "anguila"         : {"desc": "pez largo y delgado, con forma de serpiente", "precio":                                                      200},
    "cangrejo"        : {"desc": "son animales marinos con un cuerpo duro llamado exoesqueleto que los protege.", "precio":                    100},
    "orca"            : {"desc": "son mamíferos marinos grandes y poderosos,también conocidos como ballenas asesinas.", "precio":             2300},
    "pez payaso"      : {"desc": "son peces pequeños y coloridos, conocidos por sus rayas blancas y colores naranja, rojo o negro.", "precio": 250},
    "manta raya"      : {"desc": "peces grandes con aletas en forma de alas que les permiten nadar como si volaran.", "precio":                580},
    "caballito de mar": {"desc": "son peces únicos con forma de caballo", "precio":                                                           2000},
    "medusa"          : {"desc": "animales marinos de cuerpo blando y gelatinoso, con forma de campana o sombrilla.", "precio":                900},
}

carrito = []

# Menú principal
while True:
    print("\n🌊 BIENVENIDO A LA TIENDA DE ANIMALES MARINOS 🌊")
    print("1. Ver animales en lista")
    print("2. Ver animales especiales (tupla)")
    print("3. Ver animales salvajes (conjunto)")
    print("4. Ver catálogo completo")
    print("5. Comprar un animal")
    print("6. Ver carrito de compras")
    print("7. Salir")
    print("8. Pagar")
    print("9. Cifrado César")

    opcion = input("Selecciona una opción (1-7): ")

    if opcion == "1":
        print("\nAnimales disponibles (Lista):")
        for animal in animales_lista:
            print("-", animal)

    elif opcion == "2":
        print("\nAnimales especiales (Tupla):")
        for animal in animales_tupla:
            print("-", animal)

    elif opcion == "3":
        print("\nAnimales salvajes (Conjunto):")
        for animal in animales_conjunto:
            print("-", animal)

    elif opcion == "4":
        print("\n📘 Catálogo de animales:")
        for nombre, info in catalogo.items():
            print(f"- {nombre.title()}: {info['desc']} | Precio: ${info['precio']}")

    elif opcion == "5":
        eleccion = input("Escribe el nombre del animal que deseas comprar: ").lower()
        if eleccion in catalogo:
            carrito.append(eleccion)
            print(f"{eleccion.title()} ha sido añadido al carrito.")
        else:
            print("Ese animal no está en el catálogo.")

    elif opcion == "6":
        if carrito:
            total = 0
            print("\n🛒 Tu carrito de compras:")
            for animal in carrito:
                precio = catalogo[animal]["precio"]
                total += precio
                print(f"- {animal.title()}: ${precio}")
            print(f"💰 Total a pagar: ${total}")
        else:
            print("Tu carrito está vacío.")

    elif opcion == "7":
        print("Gracias por visitar nuestra tienda marina 🐙 ¡Hasta pronto!")
        break

# Datos
animales_lista = ["delfín", "pulpo", "tiburón", "ballena", "estrella de mar"]
animales_tupla = ("medusa", "caballito de mar", "manta raya")  # Animales nuevos no modificables
animales_conjunto = {"pez payaso", "orca", "cangrejo", "anguila", "calamar"}  # Sin repeticiones

# Diccionario con descripción y precio
catalogo = {
    "DELFIN"          : {"desc": "Mamífero marino inteligente", "precio":                                                                     3000},
    "pulpo"           : {"desc": "Molusco con ocho brazos", "precio":                                                                          550},
    "tiburón"         : {"desc": "Pez depredador", "precio":                                                                                  5000},
    "ballena"         : {"desc": "Gigante del océano", "precio":                                                                             10000},
    "estrella de mar" : {"desc": "Invertebrado con forma de estrella", "precio":                                                               450},
    "calamar"         : {"desc": "Molusco de cuerpo blando que vive en agua salada.", "precio":                                                350},
    "anguila"         : {"desc": "pez largo y delgado, con forma de serpiente", "precio":                                                      200},
    "cangrejo"        : {"desc": "son animales marinos con un cuerpo duro llamado exoesqueleto que los protege.", "precio":                    100},
    "orca"            : {"desc": "son mamíferos marinos grandes y poderosos,también conocidos como ballenas asesinas.", "precio":             2300},
    "pez payaso"      : {"desc": "son peces pequeños y coloridos, conocidos por sus rayas blancas y colores naranja, rojo o negro.", "precio": 250},
    "manta raya"      : {"desc": "peces grandes con aletas en forma de alas que les permiten nadar como si volaran.", "precio":                580},
    "caballito de mar": {"desc": "son peces únicos con forma de caballo", "precio":                                                           2000},
    "medusa"          : {"desc": "animales marinos de cuerpo blando y gelatinoso, con forma de campana o sombrilla.", "precio":                900},
}

carrito = []

# Menú principal
while True:
    print("\n🌊 BIENVENIDO A LA TIENDA DE ANIMALES MARINOS 🌊")
    print("1. Ver animales en lista")
    print("2. Ver animales especiales (tupla)")
    print("3. Ver animales salvajes (conjunto)")
    print("4. Ver catálogo completo")
    print("5. Comprar un animal")
    print("6. Ver carrito de compras")
    print("7. Salir")
    print("8. Pagar")  # <-- NUEVA OPCIÓN

    opcion = input("Selecciona una opción (1-8): ")

    if opcion == "1":
        print("\nAnimales disponibles (Lista):")
        for animal in animales_lista:
            print("-", animal)

    elif opcion == "2":
        print("\nAnimales especiales (Tupla):")
        for animal in animales_tupla:
            print("-", animal)

    elif opcion == "3":
        print("\nAnimales salvajes (Conjunto):")
        for animal in animales_conjunto:
            print("-", animal)

    elif opcion == "4":
        print("\n📘 Catálogo de animales:")
        for nombre, info in catalogo.items():
            print(f"- {nombre.title()}: {info['desc']} | Precio: ${info['precio']}")

    elif opcion == "5":
        eleccion = input("Escribe el nombre del animal que deseas comprar: ").lower()
        if eleccion in catalogo:
            carrito.append(eleccion)
            print(f"{eleccion.title()} ha sido añadido al carrito.")
        else:
            print("Ese animal no está en el catálogo.")

    elif opcion == "6":
        if carrito:
            total = 0
            print("\n🛒 Tu carrito de compras:")
            for animal in carrito:
                precio = catalogo[animal]["precio"]
                total += precio
                print(f"- {animal.title()}: ${precio}")
            print(f"💰 Total a pagar: ${total}")
        else:
            print("Tu carrito está vacío.")

    elif opcion == "7":
        print("Gracias por visitar nuestra tienda marina 🐙 ¡Hasta pronto!")
        break

    else:
        print("Opción inválida. Intenta nuevamente.")
# Out:
# 🌊 BIENVENIDO A LA TIENDA DE ANIMALES MARINOS 🌊
# 1. Ver animales en lista
# 2. Ver animales especiales (tupla)
# 3. Ver animales salvajes (conjunto)
# 4. Ver catálogo completo
# 5. Comprar un animal
# 6. Ver carrito de compras
# 7. Salir
# 8. Pagar
# 9. Cifrado César
#
# 📘 Catálogo de animales:
# - Delfin: Mamífero marino inteligente | Precio: $3000
# - Pulpo: Molusco con ocho brazos | Precio: $550
# - Tiburón: Pez depredador | Precio: $5000
# - Ballena: Gigante del océano | Precio: $10000
# - Estrella De Mar: Invertebrado con forma de estrella | Precio: $450
# - Calamar: Molusco de cuerpo blando que vive en agua salada. | Precio: $350
# - Anguila: pez largo y delgado, con forma de serpiente | Precio: $200
# - Cangrejo: son animales marinos con un cuerpo duro llamado exoesqueleto que los protege. | Precio: $100
# - Orca: son mamíferos marinos grandes y poderosos,también conocidos como ballenas asesinas. | Precio: $2300
# ...
